# %% [markdown]
# ## BTC 24년 1월 데이터 추가

# %%
def convert_tick_to_ohlcv(data):
    """
    Converts given Binance tick data into 1-hour interval OHLCV (Open, High, Low, Close, Volume) data.
    :param data: DataFrame with Tick data
    :return: DataFrame with the Open, High, Low, Close, Volume values
    """

    data['time'] = pd.to_datetime(data['time'], unit='ms')
    ohlcv = data.resample('1H', on='time').agg({
        'price': ['first', 'max', 'min', 'last'],
        'qty': 'sum'
})

    ohlcv.columns = ['Open', 'High', 'Low', 'Close', 'Volume']
    return ohlcv

def calculate_volatility(data, window=20):
    """
    Calculate the rolling volatility using the standard deviation of returns.
    :param data: DataFrame with OHLCV data
    :param window: The number of periods to use for calculating the standard deviation
    :return: DataFrame with the volatility values
    """

    # Calculate daily returns
    data['returns'] = data['Close'].pct_change()

    # Calculate the rolling standard deviation of returns
    data['volatility'] = data['returns'].rolling(window=window).std()

    return data

# %% [markdown]
# #### 2024 1월 데이터 concat

# %%
import pandas as pd

PATH = '../data/BTCUSDT-trades-2024-01-'

months = [str(month).zfill(2) for month in range(1, 28)]
dfs = []

for month in months:
    df = pd.read_csv(f'{PATH}{month}.csv')  # Use f-string to include the month variable
    dfs.append(df)

# Concatenate the DataFrames into a single DataFrame
result = pd.concat(dfs, ignore_index=True)

result.head()
result.to_csv('../data/BTCUSDT-trades-2024-01.csv')
# Out:
# /var/folders/nz/vk3v33x95bs4kf3ymy0z0my00000gn/T/ipykernel_4593/1880938157.py:9: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{PATH}{month}.csv')  # Use f-string to include the month variable
# /var/folders/nz/vk3v33x95bs4kf3ymy0z0my00000gn/T/ipykernel_4593/1880938157.py:9: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{PATH}{month}.csv')  # Use f-string to include the month variable

# %%
PATH = '../data/BTCUSDT-trades-2024-01-0'

months = [str(month).zfill(2) for month in range(1,4)]
dfs = []

for month in months:
    df = pd.read_csv(f'{PATH}{month}.csv')  # Use f-string to include the month variable
    dfs.append(df)

# Concatenate the DataFrames into a single DataFrame
result = pd.concat(dfs, ignore_index=True)

result.head()
result.to_csv('../data/BTCUSDT-trades-2024-01.csv')
# Out:
# /var/folders/nz/vk3v33x95bs4kf3ymy0z0my00000gn/T/ipykernel_754/223833897.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{PATH}{month}.csv')  # Use f-string to include the month variable

# %%
import pandas as pd
df = pd.read_csv('../data/BTCUSDT-trades-2024-01.csv')
df.drop(columns = 'Unnamed: 0',inplace = True)

# %%
dfc = df.copy()

# %%
df.head()
# Out:
#            id    price    qty  quote_qty          time  is_buyer_maker
# 0  4426785098  42314.0  0.033   1396.362  1.704067e+12           False
# 1  4426785099  42314.0  0.215   9097.510  1.704067e+12           False
# 2  4426785100  42314.0  0.100   4231.400  1.704067e+12           False
# 3  4426785101  42314.0  0.512  21664.768  1.704067e+12           False
# 4  4426785102  42314.0  0.007    296.198  1.704067e+12           False

# %%
df1 = convert_tick_to_ohlcv(df)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 2024-01-01 00:00:00 to 2024-01-02 05:00:00
# Freq: H
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    30 non-null     float64
#  1   High    30 non-null     float64
#  2   Low     30 non-null     float64
#  3   Close   30 non-null     float64
#  4   Volume  30 non-null     float64
# dtypes: float64(5)
# memory usage: 1.4 KB

# %%
calculate_volatility(df1, window=20)
# Out:
#                         Open     High      Low    Close    Volume   returns  \
# time
# 1970-01-01 00:00:00  43756.7  46412.7  43756.7  46412.7     0.096       NaN
# 1970-01-01 01:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# 1970-01-01 02:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# 1970-01-01 03:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# 1970-01-01 04:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# ...                      ...      ...      ...      ...       ...       ...
# 2024-01-27 19:00:00  41785.0  41977.0  41775.1  41896.4  7765.565  0.002668
# 2024-01-27 20:00:00  41896.5  42070.0  41896.4  42049.6  5408.243  0.003657
# 2024-01-27 21:00:00  42049.6  42165.6  42001.8  42137.8  5859.277  0.002098
# 2024-01-27 22:00:00  42137.8  42187.1  42057.6  42135.3  5271.863 -0.000059
# 2024-01-27 23:00:00  42135.4  42156.7  42055.4  42102.2  4399.800 -0.000786
#
#                      volatility
# time
# 1970-01-01 00:00:00         NaN
# 1970-01-01 01:00:00         NaN
# 1970-01-01 02:00:00         NaN
# 1970-01-01 03:00:00         NaN
# 1970-01-01 04:00:00         NaN
# ...                         ...
# 2024-01-27 19:00:00    0.003597
# 2024-01-27 20:00:00    0.002154
# 2024-01-27 21:00:00    0.002189
# 2024-01-27 22:00:00    0.002191
# 2024-01-27 23:00:00    0.002200
#
# [474000 rows x 7 columns]

# %%
df1
# Out:
#                         Open     High      Low    Close    Volume   returns  \
# time
# 1970-01-01 00:00:00  43756.7  46412.7  43756.7  46412.7     0.096       NaN
# 1970-01-01 01:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# 1970-01-01 02:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# 1970-01-01 03:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# 1970-01-01 04:00:00      NaN      NaN      NaN      NaN     0.000  0.000000
# ...                      ...      ...      ...      ...       ...       ...
# 2024-01-27 19:00:00  41785.0  41977.0  41775.1  41896.4  7765.565  0.002668
# 2024-01-27 20:00:00  41896.5  42070.0  41896.4  42049.6  5408.243  0.003657
# 2024-01-27 21:00:00  42049.6  42165.6  42001.8  42137.8  5859.277  0.002098
# 2024-01-27 22:00:00  42137.8  42187.1  42057.6  42135.3  5271.863 -0.000059
# 2024-01-27 23:00:00  42135.4  42156.7  42055.4  42102.2  4399.800 -0.000786
#
#                      volatility
# time
# 1970-01-01 00:00:00         NaN
# 1970-01-01 01:00:00         NaN
# 1970-01-01 02:00:00         NaN
# 1970-01-01 03:00:00         NaN
# 1970-01-01 04:00:00         NaN
# ...                         ...
# 2024-01-27 19:00:00    0.003597
# 2024-01-27 20:00:00    0.002154
# 2024-01-27 21:00:00    0.002189
# 2024-01-27 22:00:00    0.002191
# 2024-01-27 23:00:00    0.002200
#
# [474000 rows x 7 columns]

# %%
def convert_tick_to_pqi(data):

    data['time'] = pd.to_datetime(data['time'], unit='ms')
    pqi = data.resample('1H', on='time').agg({
    'price': 'mean',
    'quote_qty': 'std',
    'is_buyer_maker': 'sum'})
    
    pqi.columns = ['price','quote_qty','is_buyer_maker']
    return pqi

# %%
df2 = convert_tick_to_pqi(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df2 = convert_tick_to_pqi(data)
#
# Cell In[14], line 4, in convert_tick_to_pqi(data)
#       1 def convert_tick_to_pqi(data):
#       3     data['time'] = pd.to_datetime(data['time'], unit='ms')
# ----> 4     pqi = data.resample('1H', on='time').agg({
#       5     'price': 'mean',
#       6     'quote_qty': 'std',
#       7     'is_buyer_maker': 'sum'})
#       9     pqi.columns = ['price','quote_qty','is_buyer_maker']
#      10     return pqi
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/resample.py:352, in Resampler.aggregate(self, func, *args, **kwargs)
#     343 @doc(
#     344     _shared_docs["aggregate"],
#     345     see_also=_agg_see_also_doc,
#    (...)
#     349 )
#     350 def aggregate(self, func=None, *args, **kwargs):
# --> 352     result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     353     if result is None:
#     354         how = func
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:504, in Apply.agg_dict_like(self)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
# --> 504     results = {
#     505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:505, in <dictcomp>(.0)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
#     504     results = {
# --> 505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:275, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     272     kwargs = {}
#     274 if isinstance(func, str):
# --> 275     return getattr(self, func)(*args, **kwargs)
#     277 elif isinstance(func, abc.Iterable):
#     278     # Catch instances of lists / tuples
#     279     # but not the class list / tuple itself.
#     280     func = maybe_mangle_lambdas(func)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2456, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2451 else:
#    2452     # If we are grouping on categoricals we want unobserved categories to
#    2453     # return zero, rather than the default of NaN which the reindexing in
#    2454     # _agg_general() returns. GH #31422
#    2455     with com.temp_setattr(self, "observed", True):
# -> 2456         result = self._agg_general(
#    2457             numeric_only=numeric_only,
#    2458             min_count=min_count,
#    2459             alias="sum",
#    2460             npfunc=np.sum,
#    2461         )
#    2463     return self._reindex_output(result, fill_value=0)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1711, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1699 @final
#    1700 def _agg_general(
#    1701     self,
#    (...)
#    1706     npfunc: Callable,
#    1707 ):
#    1709     with self._group_selection_context():
#    1710         # try a cython aggregation if we can
# -> 1711         result = self._cython_agg_general(
#    1712             how=alias,
#    1713             alt=npfunc,
#    1714             numeric_only=numeric_only,
#    1715             min_count=min_count,
#    1716         )
#    1717         return result.__finalize__(self.obj, method="groupby")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1810, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1806     return result
#    1808 # TypeError -> we may have an exception in trying to aggregate
#    1809 #  continue and exclude the block
# -> 1810 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1812 if not is_ser and len(new_mgr) < orig_len:
#    1813     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1789 def array_func(values: ArrayLike) -> ArrayLike:
#    1790     try:
# -> 1791         result = self.grouper._cython_operation(
#    1792             "aggregate",
#    1793             values,
#    1794             how,
#    1795             axis=data.ndim - 1,
#    1796             min_count=min_count,
#    1797             **kwargs,
#    1798         )
#    1799     except NotImplementedError:
#    1800         # generally if we have numeric_only=False
#    1801         # and non-applicable functions
#    1802         # try to python agg
#    1803         # TODO: shouldn't min_count matter?
#    1804         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1037 ids, _, _ = self.group_info
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     698 if not isinstance(values, np.ndarray):
#     699     # i.e. ExtensionArray
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     510 if result_mask is not None:
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#     522     return res[0]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:591, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     579     func(
#     580         out=result,
#     581         counts=counts,
#    (...)
#     587         is_datetimelike=is_datetimelike,
#     588     )
#     589 elif self.how in ["sum"]:
#     590     # We support datetimelike
# --> 591     func(
#     592         out=result,
#     593         counts=counts,
#     594         values=values,
#     595         labels=comp_ids,
#     596         mask=mask,
#     597         result_mask=result_mask,
#     598         min_count=min_count,
#     599         is_datetimelike=is_datetimelike,
#     600     )
#     601 elif self.how in ["ohlc", "prod"]:
#     602     func(
#     603         result,
#     604         counts,
#    (...)
#     609         result_mask=result_mask,
#     610     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/groupby.pyx:615, in pandas._libs.groupby.group_sum()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
